# %% [markdown]
#  # Table of Contents
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item" id="toc-level0"><li><span><a href="http://localhost:8888/notebooks/CoAx/Git/Pub_Code_master/Analyses/Figures/BehResults/BehDataProcessing.ipynb#Import-&amp;-Set-Up" data-toc-modified-id="Import-&amp;-Set-Up-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Import &amp; Set Up</a></span></li><li><span><a href="http://localhost:8888/notebooks/CoAx/Git/Pub_Code_master/Analyses/Figures/BehResults/BehDataProcessing.ipynb#Import-Data" data-toc-modified-id="Import-Data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Import Data</a></span></li><li><span><a href="http://localhost:8888/notebooks/CoAx/Git/Pub_Code_master/Analyses/Figures/BehResults/BehDataProcessing.ipynb#Experiment-1" data-toc-modified-id="Experiment-1-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Experiment 1</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/CoAx/Git/Pub_Code_master/Analyses/Figures/BehResults/BehDataProcessing.ipynb#Reaction-Times" data-toc-modified-id="Reaction-Times-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Reaction Times</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/CoAx/Git/Pub_Code_master/Analyses/Figures/BehResults/BehDataProcessing.ipynb#Individual-RT's" data-toc-modified-id="Individual-RT's-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Individual RT's</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/CoAx/Git/Pub_Code_master/Analyses/Figures/BehResults/BehDataProcessing.ipynb#Trial-wise" data-toc-modified-id="Trial-wise-3.1.1.1"><span class="toc-item-num">3.1.1.1&nbsp;&nbsp;</span>Trial-wise</a></span></li><li><span><a href="http://localhost:8888/notebooks/CoAx/Git/Pub_Code_master/Analyses/Figures/BehResults/BehDataProcessing.ipynb#Mean/Median" data-toc-modified-id="Mean/Median-3.1.1.2"><span class="toc-item-num">3.1.1.2&nbsp;&nbsp;</span>Mean/Median</a></span></li></ul></li></ul></li><li><span><a href="http://localhost:8888/notebooks/CoAx/Git/Pub_Code_master/Analyses/Figures/BehResults/BehDataProcessing.ipynb#Peak-Velocity" data-toc-modified-id="Peak-Velocity-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Peak Velocity</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/CoAx/Git/Pub_Code_master/Analyses/Figures/BehResults/BehDataProcessing.ipynb#Individual-level" data-toc-modified-id="Individual-level-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Individual-level</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/CoAx/Git/Pub_Code_master/Analyses/Figures/BehResults/BehDataProcessing.ipynb#Trial-wise" data-toc-modified-id="Trial-wise-3.2.1.1"><span class="toc-item-num">3.2.1.1&nbsp;&nbsp;</span>Trial-wise</a></span></li><li><span><a href="http://localhost:8888/notebooks/CoAx/Git/Pub_Code_master/Analyses/Figures/BehResults/BehDataProcessing.ipynb#Mean/Median" data-toc-modified-id="Mean/Median-3.2.1.2"><span class="toc-item-num">3.2.1.2&nbsp;&nbsp;</span>Mean/Median</a></span></li></ul></li></ul></li><li><span><a href="http://localhost:8888/notebooks/CoAx/Git/Pub_Code_master/Analyses/Figures/BehResults/BehDataProcessing.ipynb#Selection-Error" data-toc-modified-id="Selection-Error-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>
5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Peak Velocity</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/CoAx/Git/Pub_Code_master/Analyses/Figures/BehResults/BehDataProcessing.ipynb#Individual-level" data-toc-modified-id="Individual-level-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Individual-level</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/CoAx/Git/Pub_Code_master/Analyses/Figures/BehResults/BehDataProcessing.ipynb#Trial-wise" data-toc-modified-id="Trial-wise-5.2.1.1"><span class="toc-item-num">5.2.1.1&nbsp;&nbsp;</span>Trial-wise</a></span></li><li><span><a href="http://localhost:8888/notebooks/CoAx/Git/Pub_Code_master/Analyses/Figures/BehResults/BehDataProcessing.ipynb#Mean/Median" data-toc-modified-id="Mean/Median-5.2.1.2"><span class="toc-item-num">5.2.1.2&nbsp;&nbsp;</span>Mean/Median</a></span></li></ul></li></ul></li><li><span><a href="http://localhost:8888/notebooks/CoAx/Git/Pub_Code_master/Analyses/Figures/BehResults/BehDataProcessing.ipynb#Selection-Error" data-toc-modified-id="Selection-Error-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Selection Error</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/CoAx/Git/Pub_Code_master/Analyses/Figures/BehResults/BehDataProcessing.ipynb#Individual-level" data-toc-modified-id="Individual-level-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>Individual-level</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/CoAx/Git/Pub_Code_master/Analyses/Figures/BehResults/BehDataProcessing.ipynb#Trial-wise" data-toc-modified-id="Trial-wise-5.3.1.1"><span class="toc-item-num">5.3.1.1&nbsp;&nbsp;</span>Trial-wise</a></span></li><li><span><a href="http://localhost:8888/notebooks/CoAx/Git/Pub_Code_master/Analyses/Figures/BehResults/BehDataProcessing.ipynb#Mean/Median" data-toc-modified-id="Mean/Median-5.3.1.2"><span class="toc-item-num">5.3.1.2&nbsp;&nbsp;</span>Mean/Median</a></span></li></ul></li></ul></li></ul></li></ul></div>

# %% [markdown]
# The main purpose of this script is to visualize & preprocess the behavioral data prior to running analysis. Primarily, the removal of extreme outliers & subjects giving indications that they have genuinely attempted the task will be determined in these steps

# %% [markdown]
# ## Import & Set Up

# %%
# Import packages
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

# enough with the warnings! ~ Thanks, Kyle
warnings.simplefilter('ignore', np.RankWarning)
warnings.filterwarnings("ignore", module="matplotlib")
warnings.filterwarnings("ignore", module="statsmodels")

# PLOT STYLING
# Display plots in the notebook
# %matplotlib inline 

#if you have jupyterthemes:
from jupyterthemes import jtplot
jtplot.style('grade3',context='paper', fscale=1.3)
jtplot.figsize(6, 6, 1.2)
# if you don't have jupyterthemes, but have seaborn you can use:
# sns.set(context='paper', rc={'figure.facecolor':'white'}, font_scale=1.7)

# %% [markdown]
# ## Import Data

# %%
data_path = 'D:/Rory/CoAx/Git/Pub_Code_master/Data/' # Define the path to the behavioral data
data1 = pd.read_csv(data_path + 'exp1data.csv')
data2 = pd.read_csv(data_path + 'exp2data.csv')
data3 = pd.read_csv(data_path + 'exp3data.csv')

# %% [markdown]
# ## Experiment 1

# %%
data1.head(5)
# Out:
#    subj_idx  rwd_pen  stableVar  response        rt   slxn_err    peak_V
# 0         0        3          2         0  0.288286  16.009078  0.050105
# 1         0        3          1         1  0.337928  37.178190  0.039481
# 2         0        3          2         0  0.343423  65.736960  0.009394
# 3         0        3          0         0  0.335425  15.324789  0.002480
# 4         0        3          0         1  0.222263   4.697405  0.004241

# %% [markdown]
# ### Reaction Times

# %% [markdown]
# #### Individual RT's

# %% [markdown]
# ##### Trial-wise

# %%
# ?plt.figure

# %%
fig,ax = plt.subplots(1,1);
data1.groupby('subj_idx').rt.plot();
ax.set_ylim([0,6]);
ax.set_title('RT by Subject');
ax.set_xlabel('trial');
ax.set_ylabel('RT (sec)');
# We see a couple of very slow RT's (on the order of seconds), but nothing alarming`fig,(ax1, ax2) = plt.subplots(1,2,sharey = True);

# %% [markdown]
# ##### Mean/Median

# %%
fig,(ax1, ax2) = plt.subplots(1,2,sharey = True);
data1.groupby('subj_idx').rt.mean().plot(ax=ax1);
data1.groupby('subj_idx').rt.median().plot(ax=ax2);

# %% [markdown]
# ### Peak Velocity

# %% [markdown]
# #### Individual-level

# %% [markdown]
# ##### Trial-wise

# %% [markdown]
# ##### Mean/Median

# %% [markdown]
# ### Selection Error

# %% [markdown]
# #### Individual-level

# %% [markdown]
# ##### Trial-wise

# %% [markdown]
# ##### Mean/Median

# %% [markdown]
# ## Experiment 2

# %%
data2.head(5)
# Out:
#    subj_idx  rwd_prob  rwd_pen  response        rt   slxn_err     peak_V
# 0         2       0.3        2         0  0.065335  71.610430  15.700582
# 1         2       0.3        2         1  0.327312  20.412837  14.528196
# 2         2       0.3        2         0  0.322189  59.644774   2.457386
# 3         2       0.3        2         0  0.289527  24.506692  10.272041
# 4         2       0.3        2         1  0.161990  18.994643   6.387602

# %% [markdown]
# ### Reaction Times

# %% [markdown]
# #### Individual RT's

# %% [markdown]
# ##### Trial-Wise

# %%
fig,ax = plt.subplots();
data2.groupby('subj_idx').rt.plot();
# We see a couple of very slow RT's (on the order of seconds), but nothing alarming`
# Out:
# subj_idx
# 2     Axes(0.125,0.125;0.775x0.775)
# 3     Axes(0.125,0.125;0.775x0.775)
# 4     Axes(0.125,0.125;0.775x0.775)
# 5     Axes(0.125,0.125;0.775x0.775)
# 6     Axes(0.125,0.125;0.775x0.775)
# 8     Axes(0.125,0.125;0.775x0.775)
# 9     Axes(0.125,0.125;0.775x0.775)
# 10    Axes(0.125,0.125;0.775x0.775)
# 11    Axes(0.125,0.125;0.775x0.775)
# 13    Axes(0.125,0.125;0.775x0.775)
# 14    Axes(0.125,0.125;0.775x0.775)
# 15    Axes(0.125,0.125;0.775x0.775)
# 16    Axes(0.125,0.125;0.775x0.775)
# 17    Axes(0.125,0.125;0.775x0.775)
# 18    Axes(0.125,0.125;0.775x0.775)
# 20    Axes(0.125,0.125;0.775x0.775)
# 21    Axes(0.125,0.125;0.775x0.775)
# Name: rt, dtype: object

# %% [markdown]
# ##### Mean/Median

# %%
fig,(ax1, ax2) = plt.subplots(1,2,sharey = True);
data2.groupby('subj_idx').rt.mean().plot(ax=ax1);
data2.groupby('subj_idx').rt.median().plot(ax=ax2);

# %% [markdown]
# ### Peak Velocity

# %% [markdown]
# #### Individual-level

# %% [markdown]
# ##### Trial-wise

# %% [markdown]
# ##### Mean/Median

# %% [markdown]
# ### Selection Error

# %% [markdown]
# #### Individual-level

# %% [markdown]
# ##### Trial-wise

# %% [markdown]
# ##### Mean/Median

# %% [markdown]
# ## Experiment 3

# %%
data3.head(5)
# Out:
#    subj_idx  rwd_prob  stableVar  response        rt   slxn_err     peak_V
# 0       696         3          3         1  0.226746  45.229599  36.539360
# 1       696         3          2         1  0.294754  44.961741  33.239649
# 2       696         3          2         1  0.358353  53.030909   4.769990
# 3       696         3          3         1  0.328423  24.265768   7.727274
# 4       696         3          0         0  0.065146  20.336966   2.993491

# %% [markdown]
# ### Reaction Times

# %% [markdown]
# #### Individual RT's

# %% [markdown]
# ##### Trial-Wise

# %%
fig,ax = plt.subplots()
data3.groupby('subj_idx').rt.plot();
# We see a couple of very slow RT's (on the order of seconds), but nothing alarming
# Out:
# subj_idx
# 696    Axes(0.125,0.125;0.775x0.775)
# 697    Axes(0.125,0.125;0.775x0.775)
# 698    Axes(0.125,0.125;0.775x0.775)
# 699    Axes(0.125,0.125;0.775x0.775)
# 701    Axes(0.125,0.125;0.775x0.775)
# 702    Axes(0.125,0.125;0.775x0.775)
# 703    Axes(0.125,0.125;0.775x0.775)
# 704    Axes(0.125,0.125;0.775x0.775)
# 711    Axes(0.125,0.125;0.775x0.775)
# 712    Axes(0.125,0.125;0.775x0.775)
# 713    Axes(0.125,0.125;0.775x0.775)
# 714    Axes(0.125,0.125;0.775x0.775)
# 715    Axes(0.125,0.125;0.775x0.775)
# 716    Axes(0.125,0.125;0.775x0.775)
# 717    Axes(0.125,0.125;0.775x0.775)
# 718    Axes(0.125,0.125;0.775x0.775)
# 719    Axes(0.125,0.125;0.775x0.775)
# 720    Axes(0.125,0.125;0.775x0.775)
# Name: rt, dtype: object

# %% [markdown]
# ##### Mean/Median

# %%
fig,(ax1, ax2) = plt.subplots(1,2,sharey = True);
data3.groupby('subj_idx').rt.mean().plot(ax=ax1);
data3.groupby('subj_idx').rt.median().plot(ax=ax2);

# %% [markdown]
# ### Peak Velocity

# %% [markdown]
# #### Individual-level

# %% [markdown]
# ##### Trial-wise

# %% [markdown]
# ##### Mean/Median

# %% [markdown]
# ### Selection Error

# %% [markdown]
# #### Individual-level

# %% [markdown]
# ##### Trial-wise

# %% [markdown]
# ##### Mean/Median
