# %%
from FitAnalyze import fit_and_analyze
from jupyterthemes import jtplot
jtplot.style(context='paper', fscale=1.3)
jtplot.figsize(6, 6, 1.2)
# Values below are chosen to match convergence for defined models in the convergence testing. This step should be performed only after satisfactory convergence is determined.

# %%
# Drift-rate to rwd/pen tradeoff
e2m5 = fit_and_analyze(experiment=2, depends_on={'v':'rwd_pen'}, bias=False, include=['v', 't', 'a'], nsample=1500, nburn=500, p_outlier=.05, mname='Exp2Mod5', saveplots=True, stats=True)
# Out:
# C:\Users\Rory\Anaconda3\lib\site-packages\IPython\parallel.py:13: ShimWarning: The `IPython.parallel` package has been deprecated. You should import from ipyparallel instead.
#   "You should import from ipyparallel instead.", ShimWarning)
# C:\Users\Rory\Anaconda3\lib\site-packages\scipy\optimize\optimize.py:1850: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# C:\Users\Rory\Anaconda3\lib\site-packages\pymc\Node.py:403: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   self.__name__ = input['__name__']
#  [-----------------100%-----------------] 1500 of 1500 complete in 230.2 sec
# C:\Users\Rory\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# ...

# %%
e2m5.plot_posterior_quantiles(hexbin=False,save=True,samples=250)

# %%
# Drift-rate to rwd prob
e2m6 = fit_and_analyze(experiment=2, depends_on={'v':'rwd_prob'}, bias=False, include=['v', 't', 'a'], nsample=1500, nburn=500, p_outlier=.05, mname='Exp2Mod6', saveplots=True, stats=True)
# Out:
# C:\Users\Rory\Anaconda3\lib\site-packages\scipy\optimize\optimize.py:1850: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
#  [-----------------100%-----------------] 1500 of 1500 complete in 266.4 sec                        mean          std        2.5q        25q        50q        75q      97.5q       mc err
# a                   0.832874    0.0467399    0.748617   0.802799   0.829865   0.860267   0.932993   0.00167009
# a_std               0.174172    0.0387435      0.1174   0.146406   0.168057   0.194738   0.273474   0.00174749
# a_subj.2            0.653585    0.0125885    0.628783   0.644778    0.65452   0.661343   0.680449  0.000508455
# a_subj.3            0.946808    0.0391741    0.874925   0.922734   0.944043   0.968992    1.03488   0.00290343
# a_subj.4             0.92251    0.0204626    0.883982   0.908591   0.922669   0.936559   0.962952   0.00100716
# ...

# %%
e2m6.plot_posterior_quantiles(hexbin=False, save=True, samples=250)

# %%
# Drift-rate to both task params
e2m1 = fit_and_analyze(experiment=2, depends_on={'v':['rwd_pen','rwd_prob']}, bias=False, include=['v', 't', 'a'], nsample=3000, nburn=1500, p_outlier=.05, mname='Exp2Mod1', saveplots=True, stats=True)
# Out:
# C:\Users\Rory\Anaconda3\lib\site-packages\scipy\optimize\optimize.py:1850: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
#  [-----------------100%-----------------] 3000 of 3000 complete in 591.0 sec                             mean          std         2.5q         25q         50q        75q      97.5q       mc err
# a                         1.03832     0.115536     0.844591    0.959643     1.02747    1.10254    1.30261   0.00516423
# a_std                    0.433465     0.114293      0.28325    0.354243    0.409338   0.487531   0.736103   0.00578977
# a_subj.2                 0.725959    0.0157995     0.696283    0.714943    0.725463   0.736585   0.757811  0.000568546
# a_subj.3                 0.971158    0.0401548     0.895354    0.944287    0.970179   0.997169    1.05515   0.00272927
# a_subj.4                  0.93825    0.0204414     0.899237    0.924585    0.938037   0.951011   0.979168  0.000848697
# ...

# %%
e2m1.plot_posterior_quantiles(hexbin=False,save=True, samples=250)

# %%
# Drift-rate to rwd/pen tradeoff with free bias
e2m10 = fit_and_analyze(experiment=2, depends_on={'v':'rwd_pen'}, bias=True, include=['v', 't', 'a','z'], nsample=1500, nburn=500, p_outlier=.05, mname='Exp2m10', saveplots=True, stats=True)
# Out:
# C:\Users\Rory\Anaconda3\lib\site-packages\scipy\optimize\optimize.py:1850: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
#  [-----------------100%-----------------] 1501 of 1500 complete in 298.5 sec                    mean          std       2.5q        25q         50q        75q      97.5q       mc err
# a               0.716489    0.0358899   0.651539   0.692526    0.715091   0.738096   0.796644   0.00146687
# a_std           0.138078    0.0296252  0.0958937   0.117945    0.133379   0.152318   0.208766   0.00129541
# a_subj.2        0.655356    0.0123053   0.631226   0.646773     0.65569   0.664016   0.679228  0.000529009
# a_subj.3        0.606838    0.0112454   0.586497    0.59907    0.606641    0.61477   0.629477  0.000561974
# a_subj.4        0.809899    0.0147965   0.781079   0.800118     0.80955   0.819792   0.840984  0.000599295
# ...

# %%
e2m10.plot_posterior_quantiles(hexbin=False,save=True, samples=250)

# %%
# Drift-rate to rwd prob with free bias
e2m11 = fit_and_analyze(experiment=2, depends_on={'v':'rwd_prob'}, bias=True, include=['v', 't', 'a','z'], nsample=1500, nburn=500, p_outlier=.05, mname='Exp2Mod11', saveplots=True, stats=True)
# Out:
# C:\Users\Rory\Anaconda3\lib\site-packages\scipy\optimize\optimize.py:1850: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
#  [-----------------100%-----------------] 1500 of 1500 complete in 329.0 sec                        mean          std       2.5q        25q        50q         75q      97.5q       mc err
# a                    0.84307    0.0487996   0.754366   0.811872   0.840727    0.872736    0.94784   0.00186177
# a_std               0.180149    0.0412108   0.122051   0.152158   0.172922    0.199367   0.282638   0.00182613
# a_subj.2             0.65866    0.0129024   0.634056   0.649843   0.659159    0.667469   0.683046  0.000520043
# a_subj.3            0.947295    0.0389574   0.879236   0.920049   0.944404    0.973581    1.02775   0.00294138
# a_subj.4             0.92138    0.0208733   0.883631   0.906009   0.919987    0.936466   0.960836   0.00105577
# ...

# %%
e2m11.plot_posterior_quantiles(hexbin=False,save=True, samples=250)

# %%
# Drift-rate to task params with free bias model
e2m9 = fit_and_analyze(experiment=2, depends_on={'v':['rwd_pen','rwd_prob']}, bias=True, include=['v', 't', 'a','z'], nsample=1500, nburn=500, p_outlier=.05, mname='Exp2Mod9', saveplots=True, stats=True)
# Out:
# C:\Users\Rory\Anaconda3\lib\site-packages\scipy\optimize\optimize.py:1850: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
#  [-----------------100%-----------------] 1500 of 1500 complete in 386.1 sec                            mean          std        2.5q         25q         50q        75q       97.5q       mc err
# a                        1.06746     0.122443    0.868987    0.982987     1.05277    1.13187     1.36199   0.00653927
# a_std                     0.4599      0.12326    0.294858     0.37545     0.43245   0.518103    0.811843   0.00731944
# a_subj.2                 0.73098    0.0151281    0.702176    0.720314    0.731285    0.74148    0.760026  0.000809255
# a_subj.3                0.971974    0.0418425    0.896015    0.942109    0.969819    1.00128     1.05943   0.00328154
# a_subj.4                0.940266    0.0212077    0.902619    0.926156    0.939741   0.953149    0.985264   0.00103156
# ...

# %%
e2m9.plot_posterior_quantiles(hexbin=False,save=True, samples=250)
