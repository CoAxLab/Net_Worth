# %%
# Start cluster. Note: to get this to work, I run the cell once, then "Restart and Clear all output" then run a second time.
# !ipcluster start -n 3 #3 CPUs, one for each chain we want to test
chains = 3
# Out:
# 2017-06-08 00:33:03.875 [IPClusterStart] CRITICAL | Cluster is already running with [pid=4780]. use "ipcluster stop" to stop the cluster.

# %%
# Imports
from ModelConvergenceTest import test_convergence
import Exp3models
# %matplotlib inline

from jupyterthemes import jtplot
jtplot.style(context='paper', fscale=1.3)
jtplot.figsize(6, 6, 1.2)

# %%
# Pure drift-rate: stable target variance model
rhat5 = test_convergence(Exp3models.run_exp3mod5, chains, saveplots=True)
rhat5
# Out:
# C:\Users\Rory\Anaconda3\lib\site-packages\IPython\parallel.py:13: ShimWarning: The `IPython.parallel` package has been deprecated. You should import from ipyparallel instead.
#   "You should import from ipyparallel instead.", ShimWarning)
# Plotting a
# Plotting a_std
# Plotting v(0)
# Plotting v(1)
# Plotting v(2)
# Plotting v(3)
# Plotting v_std
# Plotting t
# Plotting t_std
# {'a': 0.9997352031879746,
#  'a_std': 1.0008421075309324,
#  'a_subj.696': 0.99951278052774128,
#  'a_subj.697': 1.0005347175256749,
#  'a_subj.698': 1.0013341996555045,
#  'a_subj.699': 1.001063461340991,
#  'a_subj.701': 1.0004491926559373,
#  'a_subj.702': 1.0006948737800772,
#  'a_subj.703': 1.0014296575638089,
#  'a_subj.704': 0.99965650756306579,
#  'a_subj.711': 0.99922988731644657,
#  'a_subj.712': 1.0009392220540003,
#  'a_subj.713': 1.0048108072019681,
#  'a_subj.714': 0.99923131554445466,
#  'a_subj.715': 1.0000521173860655,
#  'a_subj.716': 1.0006938080404373,
#  'a_subj.717': 1.0015643918433268,
# ...

# %%
# Pure drift-rate: rwd prob model
rhat6 = test_convergence(Exp3models.run_exp3mod6, chains, saveplots=True)
rhat6
# Out:
# Plotting a
# Plotting a_std
# Plotting v(0)
# Plotting v(1)
# Plotting v(2)
# Plotting v(3)
# Plotting v_std
# Plotting t
# Plotting t_std
# {'a': 0.99967025656990416,
#  'a_std': 1.0027113920757189,
#  'a_subj.696': 1.0066754675175378,
#  'a_subj.697': 0.99954108471148417,
#  'a_subj.698': 1.0029434317910022,
#  'a_subj.699': 1.0014844848021962,
#  'a_subj.701': 1.0001934294957477,
#  'a_subj.702': 1.0008657307174151,
#  'a_subj.703': 0.99953196718530224,
#  'a_subj.704': 1.0025965221416733,
#  'a_subj.711': 0.99995528070842277,
#  'a_subj.712': 1.0026822036545164,
#  'a_subj.713': 0.99930258104834768,
#  'a_subj.714': 1.0002366883519294,
#  'a_subj.715': 1.0006121708146978,
#  'a_subj.716': 0.99922296950586909,
#  'a_subj.717': 0.99950168137755691,
#  'a_subj.718': 1.0044995039851481,
#  'a_subj.719': 1.0005817964937389,
#  'a_subj.720': 1.0009347921808607,
#  't': 1.0004952088751757,
#  't_std': 1.0024548657134678,
#  't_subj.696': 1.0009473185783615,
# ...

# %%
# Pure Drift-rate: task params model
rhat1 = test_convergence(Exp3models.run_exp3mod1, chains, saveplots=True)
rhat1
# Out:
# Plotting a
# Plotting a_std
# Plotting v(0.0)
# Plotting v(0.1)
# Plotting v(0.2)
# Plotting v(0.3)
# Plotting v(1.0)
# Plotting v(1.1)
# Plotting v(1.2)
# Plotting v(1.3)
# Plotting v(2.0)
# Plotting v(2.1)
# Plotting v(2.2)
# Plotting v(2.3)
# Plotting v(3.0)
# Plotting v(3.1)
# Plotting v(3.2)
# Plotting v(3.3)
# Plotting v_std
# Plotting t
# Plotting t_std
# C:\Users\Rory\Anaconda3\lib\site-packages\matplotlib\pyplot.py:516: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# {'a': 0.99923444587676147,
#  'a_std': 1.0004993247574796,
#  'a_subj.696': 1.0008639522142051,
#  'a_subj.697': 1.0009896217387351,
#  'a_subj.698': 1.0050809676736034,
#  'a_subj.699': 1.0021477577961413,
#  'a_subj.701': 1.0101747007858752,
# ...

# %%
# Drift-rate:stable target variance with free bias model
rhat10 = test_convergence(Exp3models.run_exp3mod10, chains, saveplots=True)
rhat10
# Out:
# Plotting a
# Plotting a_std
# Plotting v(0)
# Plotting v(1)
# Plotting v(2)
# Plotting v(3)
# Plotting v_std
# Plotting t
# Plotting t_std
# Plotting z
# Plotting z_std
# {'a': 0.99949101895530568,
#  'a_std': 0.99963959066462482,
#  'a_subj.696': 1.0004493884839585,
#  'a_subj.697': 1.0013610123941676,
#  'a_subj.698': 1.0066681919922531,
#  'a_subj.699': 1.0000630359161948,
#  'a_subj.701': 1.0088706310732567,
#  'a_subj.702': 1.0028789605879063,
#  'a_subj.703': 0.99978344748780246,
#  'a_subj.704': 1.0007950905472383,
#  'a_subj.711': 0.99922091032302729,
#  'a_subj.712': 1.0014149421970222,
#  'a_subj.713': 1.0094877459699392,
#  'a_subj.714': 1.0023958672276039,
#  'a_subj.715': 1.0009076177159824,
#  'a_subj.716': 1.0002579920224361,
#  'a_subj.717': 1.0001958263321655,
#  'a_subj.718': 0.99938057486559706,
#  'a_subj.719': 1.0005494421168541,
#  'a_subj.720': 0.99955084097053637,
#  't': 0.99983074475901823,
#  't_std': 1.0036929560845338,
# ...

# %%
# Drift-rate: rwd prob with free bias model
rhat11 = test_convergence(Exp3models.run_exp3mod11, chains, saveplots=True)
rhat11
# Out:
# C:\Users\Rory\Anaconda3\lib\site-packages\IPython\parallel.py:13: ShimWarning: The `IPython.parallel` package has been deprecated. You should import from ipyparallel instead.
#   "You should import from ipyparallel instead.", ShimWarning)
# Plotting a
# Plotting a_std
# Plotting v(0)
# Plotting v(1)
# Plotting v(2)
# Plotting v(3)
# Plotting v_std
# Plotting t
# Plotting t_std
# Plotting z
# Plotting z_std
# {'a': 0.99925032029970928,
#  'a_std': 0.99920618705005315,
#  'a_subj.696': 1.0037036712314686,
#  'a_subj.697': 0.99972899301868379,
#  'a_subj.698': 1.0010295785041223,
#  'a_subj.699': 1.0025279409815808,
#  'a_subj.701': 1.0035405892213105,
#  'a_subj.702': 1.0021352222122875,
#  'a_subj.703': 1.0082598035824644,
#  'a_subj.704': 1.0073567490188724,
#  'a_subj.711': 0.99954875889428596,
#  'a_subj.712': 0.99954369170638091,
#  'a_subj.713': 1.0043206896572883,
#  'a_subj.714': 0.99985357411625009,
#  'a_subj.715': 1.0007738579867509,
#  'a_subj.716': 1.0034660056921048,
# ...

# %%
# Drift-rate: task params with free bias model
rhat9 = test_convergence(Exp3models.run_exp3mod9, chains, saveplots=True)
rhat9
# Out:
# C:\Users\Rory\Anaconda3\lib\site-packages\IPython\parallel.py:13: ShimWarning: The `IPython.parallel` package has been deprecated. You should import from ipyparallel instead.
#   "You should import from ipyparallel instead.", ShimWarning)
# Plotting a
# Plotting a_std
# Plotting v(0.0)
# Plotting v(0.1)
# Plotting v(0.2)
# Plotting v(0.3)
# Plotting v(1.0)
# Plotting v(1.1)
# Plotting v(1.2)
# Plotting v(1.3)
# Plotting v(2.0)
# Plotting v(2.1)
# Plotting v(2.2)
# Plotting v(2.3)
# Plotting v(3.0)
# Plotting v(3.1)
# Plotting v(3.2)
# Plotting v(3.3)
# Plotting v_std
# Plotting t
# Plotting t_std
# C:\Users\Rory\Anaconda3\lib\site-packages\matplotlib\pyplot.py:516: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Plotting z
# ...
