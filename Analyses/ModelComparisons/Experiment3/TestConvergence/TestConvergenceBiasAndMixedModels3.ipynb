# %%
# Start cluster. Note: to get this to work, I run the cell once, then "Restart and Clear all output" then run a second time.
# !ipcluster start -n 3 #3 CPUs, one for each chain we want to test
chains = 3
# Out:
# 2017-06-08 01:35:03.606 [IPClusterStart] CRITICAL | Cluster is already running with [pid=4780]. use "ipcluster stop" to stop the cluster.

# %%
# Imports
from ModelConvergenceTest import test_convergence
import Exp3models
# %matplotlib inline

from jupyterthemes import jtplot
jtplot.style(context='paper', fscale=1.3)
jtplot.figsize(6, 6, 1.2)

# %%
# Bias: stable target variance model
rhat7 = test_convergence(Exp3models.run_exp3mod7, chains, saveplots=True)
rhat7
# Out:
# C:\Users\Rory\Anaconda3\lib\site-packages\IPython\parallel.py:13: ShimWarning: The `IPython.parallel` package has been deprecated. You should import from ipyparallel instead.
#   "You should import from ipyparallel instead.", ShimWarning)
# Plotting a
# Plotting a_std
# Plotting v
# Plotting v_std
# Plotting t
# Plotting t_std
# Plotting z(0)
# Plotting z(1)
# Plotting z(2)
# Plotting z(3)
# Plotting z_std
# {'a': 0.99967896013386603,
#  'a_std': 1.0005077558756663,
#  'a_subj.696': 1.0004665843437799,
#  'a_subj.697': 0.99994682927111145,
#  'a_subj.698': 1.0043332234770896,
#  'a_subj.699': 1.0004750722217275,
#  'a_subj.701': 1.0017876289207093,
#  'a_subj.702': 1.0003926557828107,
#  'a_subj.703': 1.001982613906705,
#  'a_subj.704': 1.0005796718592292,
#  'a_subj.711': 0.99936100649813731,
#  'a_subj.712': 0.99953971017711618,
#  'a_subj.713': 1.0052290367070178,
#  'a_subj.714': 0.99980314037176388,
#  'a_subj.715': 1.0003592959730825,
#  'a_subj.716': 1.0006142868669612,
# ...

# %%
# Bias: rwd prob model
rhat8 = test_convergence(Exp3models.run_exp3mod8, chains, saveplots=True)
rhat8
# Out:
# Plotting a
# Plotting a_std
# Plotting v
# Plotting v_std
# Plotting t
# Plotting t_std
# Plotting z(0)
# Plotting z(1)
# Plotting z(2)
# Plotting z(3)
# Plotting z_std
# {'a': 0.99984314310949485,
#  'a_std': 1.0012836771163762,
#  'a_subj.696': 0.9995399755108656,
#  'a_subj.697': 1.0029273951717632,
#  'a_subj.698': 0.99932906597465632,
#  'a_subj.699': 0.99934778958848924,
#  'a_subj.701': 1.0066757807168931,
#  'a_subj.702': 0.9993253754645548,
#  'a_subj.703': 0.99927176254575423,
#  'a_subj.704': 1.0000802420612953,
#  'a_subj.711': 0.99928085804512912,
#  'a_subj.712': 0.9997883025470109,
#  'a_subj.713': 0.99992718693485327,
#  'a_subj.714': 1.0013170839882162,
#  'a_subj.715': 1.0026349812978599,
#  'a_subj.716': 0.99930648279380596,
#  'a_subj.717': 1.0018620605263524,
#  'a_subj.718': 1.0137851086875389,
#  'a_subj.719': 1.0016761993996546,
#  'a_subj.720': 1.0007476573034424,
#  't': 1.0000971741290881,
#  't_std': 1.001608399216992,
# ...

# %%
# Bias: task params model
rhat2 = test_convergence(Exp3models.run_exp3mod2, chains, saveplots=True)
rhat2
# Out:
# Plotting a
# Plotting a_std
# Plotting v
# Plotting v_std
# Plotting t
# Plotting t_std
# Plotting z(0.0)
# Plotting z(0.1)
# Plotting z(0.2)
# Plotting z(0.3)
# Plotting z(1.0)
# Plotting z(1.1)
# Plotting z(1.2)
# Plotting z(1.3)
# Plotting z(2.0)
# Plotting z(2.1)
# Plotting z(2.2)
# Plotting z(2.3)
# Plotting z(3.0)
# Plotting z(3.1)
# Plotting z(3.2)
# C:\Users\Rory\Anaconda3\lib\site-packages\matplotlib\pyplot.py:516: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Plotting z(3.3)
# Plotting z_std
# {'a': 1.0033101242393994,
#  'a_std': 1.0048264265077125,
#  'a_subj.696': 0.99925275626885512,
#  'a_subj.697': 1.0123214966214411,
#  'a_subj.698': 1.000927509295777,
#  'a_subj.699': 1.0027407306525322,
# ...

# %%
# Drift-rate: rwd prob, bias: stable target variance model
rhat3 = test_convergence(Exp3models.run_exp3mod3, chains, saveplots=True)
rhat3 # redo at higher sample/burn rate
# Out:
# C:\Users\Rory\Anaconda3\lib\site-packages\IPython\parallel.py:13: ShimWarning: The `IPython.parallel` package has been deprecated. You should import from ipyparallel instead.
#   "You should import from ipyparallel instead.", ShimWarning)
# Plotting a
# Plotting a_std
# Plotting v(0)
# Plotting v(1)
# Plotting v(2)
# Plotting v(3)
# Plotting v_std
# Plotting t
# Plotting t_std
# Plotting z(0)
# Plotting z(1)
# Plotting z(2)
# Plotting z(3)
# Plotting z_std
# {'a': 1.0018207160858659,
#  'a_std': 1.0021485179206235,
#  'a_subj.696': 0.99999799248392307,
#  'a_subj.697': 1.0005000472180066,
#  'a_subj.698': 0.99961393770024387,
#  'a_subj.699': 1.0049274973745821,
#  'a_subj.701': 1.0034977741569979,
#  'a_subj.702': 0.99966357451089127,
#  'a_subj.703': 1.0009467196485109,
#  'a_subj.704': 1.0004822156543733,
#  'a_subj.711': 1.0029758895770542,
#  'a_subj.712': 0.99966823007408012,
#  'a_subj.713': 1.0057567998067791,
#  'a_subj.714': 1.0095181297248195,
# ...

# %%
# Drift-rate: stable target variance, bias: rwd prob model
rhat4 = test_convergence(Exp3models.run_exp3mod4, chains, saveplots=True)
rhat4
# Out:
# Plotting a
# Plotting a_std
# Plotting v(0)
# Plotting v(1)
# Plotting v(2)
# Plotting v(3)
# Plotting v_std
# Plotting t
# Plotting t_std
# Plotting z(0)
# Plotting z(1)
# Plotting z(2)
# Plotting z(3)
# Plotting z_std
# {'a': 0.99982588177869736,
#  'a_std': 1.0030780223944611,
#  'a_subj.696': 1.0018900365667764,
#  'a_subj.697': 1.0027747132757261,
#  'a_subj.698': 1.002963402531478,
#  'a_subj.699': 0.99958916978542312,
#  'a_subj.701': 1.0075215820022816,
#  'a_subj.702': 0.99985658270114475,
#  'a_subj.703': 1.0038395696070876,
#  'a_subj.704': 1.0051167147213733,
#  'a_subj.711': 1.0009067445922561,
#  'a_subj.712': 1.0005442392387671,
#  'a_subj.713': 1.0011086753713396,
#  'a_subj.714': 1.0020610285645688,
#  'a_subj.715': 1.0028452070466876,
#  'a_subj.716': 1.0041860217521879,
#  'a_subj.717': 1.0009079105548604,
#  'a_subj.718': 1.0028607392224052,
#  'a_subj.719': 0.99958076374171634,
#  'a_subj.720': 1.0066699603765326,
#  't': 1.0001913414241683,
# ...
